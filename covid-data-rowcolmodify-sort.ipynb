# %%
import pandas as pd

# %%
df = pd.read_csv('download.csv')

# %%
df = pd.DataFrame(df)

# %%
df.head(2)
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  10/09/2020   10      9  2020     24       2             Afghanistan    AF
# 1  09/09/2020    9      9  2020     26       3             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           1.098793
# 1                                           1.180282

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.columns
# Out:
# Index(['DATEREP', 'DAY', 'MONTH', 'YEAR', 'CASES', 'DEATHS',
#        'COUNTRIESANDTERRITORIES', 'GEOID', 'COUNTRYTERRITORYCODE',
#        'POPDATA2019', 'CONTINENTEXP',
#        'CUMULATIVE_NUMBER_FOR_14_DAYS_OF_COVID-19_CASES_PER_100000'],
#       dtype='object')

# %%
df.head(2)
# Out:
#       DATEREP  DAY  MONTH  YEAR  CASES  DEATHS COUNTRIESANDTERRITORIES GEOID  \
# 0  10/09/2020   10      9  2020     24       2             Afghanistan    AF
# 1  09/09/2020    9      9  2020     26       3             Afghanistan    AF
#
#   COUNTRYTERRITORYCODE  POPDATA2019 CONTINENTEXP  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
#
#    CUMULATIVE_NUMBER_FOR_14_DAYS_OF_COVID-19_CASES_PER_100000
# 0                                           1.098793
# 1                                           1.180282

# %%
df.columns = df.columns.str.replace('CUMULATIVE_NUMBER_FOR_14_DAYS_OF_COVID-19_CASES_PER_100000', 'DENSITY14POP')

# %%
df.head(2)
# Out:
#       DATEREP  DAY  MONTH  YEAR  CASES  DEATHS COUNTRIESANDTERRITORIES GEOID  \
# 0  10/09/2020   10      9  2020     24       2             Afghanistan    AF
# 1  09/09/2020    9      9  2020     26       3             Afghanistan    AF
#
#   COUNTRYTERRITORYCODE  POPDATA2019 CONTINENTEXP  DENSITY14POP
# 0                  AFG   38041757.0         Asia      1.098793
# 1                  AFG   38041757.0         Asia      1.180282

# %%
df.columns = [x.lower() for x in df.columns]
df.tail(2)
# Out:
#           daterep  day  month  year  cases  deaths countriesandterritories  \
# 41835  22/03/2020   22      3  2020      1       0                Zimbabwe
# 41836  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoid countryterritorycode  popdata2019 continentexp  density14pop
# 41835    ZW                  ZWE   14645473.0       Africa           NaN
# 41836    ZW                  ZWE   14645473.0       Africa           NaN

# %%
df.rename(columns={'countriesandterritories': 'countandterr', 'countryterritorycode': 'code'}, inplace=True)

# %%
df.loc[2, ['density14pop', 'popdata2019']] = [2.45248794422, 2.80418e+07]  # istediğin col değerini değiştirmek için kullan

# %%
df.loc[2]
# Out:
# daterep          08/09/2020
# day                       8
# month                     9
# year                   2020
# cases                    96
# deaths                    3
# countandterr    Afghanistan
# geoid                    AF
# code                    AFG
# popdata2019     2.80418e+07
# continentexp           Asia
# density14pop        2.45249
# Name: 2, dtype: object

# %%
df.loc[2, 'popdata2019'] = 3.80418e+07
df.loc[2]                            #col ve row lar liste [] olarak tutuluyor...
#loc ve iloc cok öenmli ve unutulan yapılan hatalardandır
# Out:
# daterep          08/09/2020
# day                       8
# month                     9
# year                   2020
# cases                    96
# deaths                    3
# countandterr    Afghanistan
# geoid                    AF
# code                    AFG
# popdata2019     3.80418e+07
# continentexp           Asia
# density14pop        2.45249
# Name: 2, dtype: object

# %%
filt = (df['deaths'] == 3)
df[filt]      #bir değeri değiştirmek istiyorsan loc ve iloc kullanmalısın
# Out:
#           daterep  day  month  year  cases  deaths countandterr geoid code  \
# 1      09/09/2020    9      9  2020     26       3  Afghanistan    AF  AFG
# 2      08/09/2020    8      9  2020     96       3  Afghanistan    AF  AFG
# 7      03/09/2020    3      9  2020     38       3  Afghanistan    AF  AFG
# 102    31/05/2020   31      5  2020    866       3  Afghanistan    AF  AFG
# 119    14/05/2020   14      5  2020    259       3  Afghanistan    AF  AFG
# ...           ...  ...    ...   ...    ...     ...          ...   ...  ...
# 41670  03/09/2020    3      9  2020     79       3     Zimbabwe    ZW  ZWE
# 41686  18/08/2020   18      8  2020     47       3     Zimbabwe    ZW  ZWE
# 41698  06/08/2020    6      8  2020    118       3     Zimbabwe    ZW  ZWE
# 41718  17/07/2020   17      7  2020    273       3     Zimbabwe    ZW  ZWE
# 41725  10/07/2020   10      7  2020     41       3     Zimbabwe    ZW  ZWE
#
#        popdata2019 continentexp  density14pop
# ...

# %%
filtZWE = (df['code'] == 'ZWE')
zimbab = df[filtZWE]
zimbab['countandterr'].str.lower()
zimbab
# Out:
#           daterep  day  month  year  cases  deaths countandterr geoid code  \
# 41663  10/09/2020   10      9  2020     41       4     Zimbabwe    ZW  ZWE
# 41664  09/09/2020    9      9  2020     90       8     Zimbabwe    ZW  ZWE
# 41665  08/09/2020    8      9  2020    321       3     Zimbabwe    ZW  ZWE
# 41666  07/09/2020    7      9  2020    140       1     Zimbabwe    ZW  ZWE
# 41667  06/09/2020    6      9  2020      0       0     Zimbabwe    ZW  ZWE
# ...           ...  ...    ...   ...    ...     ...          ...   ...  ...
# 41832  25/03/2020   25      3  2020      0       0     Zimbabwe    ZW  ZWE
# 41833  24/03/2020   24      3  2020      0       1     Zimbabwe    ZW  ZWE
# 41834  23/03/2020   23      3  2020      0       0     Zimbabwe    ZW  ZWE
# 41835  22/03/2020   22      3  2020      1       0     Zimbabwe    ZW  ZWE
# 41836  21/03/2020   21      3  2020      1       0     Zimbabwe    ZW  ZWE
#
#        popdata2019 continentexp  density14pop
# ...

# %%
df['countandterr'].apply(len)  #apply ile herhangibir fonksiyon kullanılabilir.
#özelillkle lambda fonk. lar kullanılabilir.
# Out:
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
#          ..
# 41832     8
# 41833     8
# 41834     8
# 41835     8
# 41836     8
# Name: countandterr, Length: 41837, dtype: int64

# %%
zwe = zimbab[['deaths','cases','density14pop']]
zwe
# Out:
#        deaths  cases  density14pop
# 41663       4     41      8.043441
# 41664       8     90      8.139034
# 41665       3    321      8.384844
# 41666       1    140      7.148967
# 41667       0      0      6.445678
# ...       ...    ...           ...
# 41832       0      0           NaN
# 41833       1      0           NaN
# 41834       0      0           NaN
# 41835       0      1           NaN
# 41836       0      1           NaN
#
# [174 rows x 3 columns]

# %%
df.apply(len, axis='columns')  # defaul secenek rows dur, her columun  uzunlugunu soyler.
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 41832    12
# 41833    12
# 41834    12
# 41835    12
# 41836    12
# Length: 41837, dtype: int64

# %%
len(df)
# Out:
# 41837

# %%
#df.apply(pd.Series.min)   => camparable labildiğinde kullanırsın

# %%
#df.applymap(str.lower)
#df['first'] = df['first'].map({'corey': 'chris', 'jane': 'mary'})  for substitue (or replace...)

# %%
#df['deaths'].map({0:False, ??oother: True})

# %%
df.drop(columns=['geoid'], inplace=True)  # remove a column
df
# Out:
#           daterep  day  month  year  cases  deaths countandterr code  \
# 0      10/09/2020   10      9  2020     24       2  Afghanistan  AFG
# 1      09/09/2020    9      9  2020     26       3  Afghanistan  AFG
# 2      08/09/2020    8      9  2020     96       3  Afghanistan  AFG
# 3      07/09/2020    7      9  2020     74       2  Afghanistan  AFG
# 4      06/09/2020    6      9  2020     20       0  Afghanistan  AFG
# ...           ...  ...    ...   ...    ...     ...          ...  ...
# 41832  25/03/2020   25      3  2020      0       0     Zimbabwe  ZWE
# 41833  24/03/2020   24      3  2020      0       1     Zimbabwe  ZWE
# 41834  23/03/2020   23      3  2020      0       0     Zimbabwe  ZWE
# 41835  22/03/2020   22      3  2020      1       0     Zimbabwe  ZWE
# 41836  21/03/2020   21      3  2020      1       0     Zimbabwe  ZWE
#
#        popdata2019 continentexp  density14pop
# 0       38041757.0         Asia      1.098793
# ...

# %%
df.append({'first': 'tony'}, ignore_index=True)  #add a single row for an nonexisting col
#df.append(df2, ignore_index=True)  => new rows appenden in existing dataframe
# Out:
#           daterep   day  month    year  cases  deaths countandterr code  \
# 0      10/09/2020  10.0    9.0  2020.0   24.0     2.0  Afghanistan  AFG
# 1      09/09/2020   9.0    9.0  2020.0   26.0     3.0  Afghanistan  AFG
# 2      08/09/2020   8.0    9.0  2020.0   96.0     3.0  Afghanistan  AFG
# 3      07/09/2020   7.0    9.0  2020.0   74.0     2.0  Afghanistan  AFG
# 4      06/09/2020   6.0    9.0  2020.0   20.0     0.0  Afghanistan  AFG
# ...           ...   ...    ...     ...    ...     ...          ...  ...
# 41833  24/03/2020  24.0    3.0  2020.0    0.0     1.0     Zimbabwe  ZWE
# 41834  23/03/2020  23.0    3.0  2020.0    0.0     0.0     Zimbabwe  ZWE
# 41835  22/03/2020  22.0    3.0  2020.0    1.0     0.0     Zimbabwe  ZWE
# 41836  21/03/2020  21.0    3.0  2020.0    1.0     0.0     Zimbabwe  ZWE
# 41837         NaN   NaN    NaN     NaN    NaN     NaN          NaN  NaN
#
#        popdata2019 continentexp  density14pop first
# ...

# %%
df.drop(index=2)    # belirlenen indexi tamamen siler
# Out:
#           daterep  day  month  year  cases  deaths countandterr code  \
# 0      10/09/2020   10      9  2020     24       2  Afghanistan  AFG
# 1      09/09/2020    9      9  2020     26       3  Afghanistan  AFG
# 3      07/09/2020    7      9  2020     74       2  Afghanistan  AFG
# 4      06/09/2020    6      9  2020     20       0  Afghanistan  AFG
# 5      05/09/2020    5      9  2020     16       0  Afghanistan  AFG
# ...           ...  ...    ...   ...    ...     ...          ...  ...
# 41832  25/03/2020   25      3  2020      0       0     Zimbabwe  ZWE
# 41833  24/03/2020   24      3  2020      0       1     Zimbabwe  ZWE
# 41834  23/03/2020   23      3  2020      0       0     Zimbabwe  ZWE
# 41835  22/03/2020   22      3  2020      1       0     Zimbabwe  ZWE
# 41836  21/03/2020   21      3  2020      1       0     Zimbabwe  ZWE
#
#        popdata2019 continentexp  density14pop
# 0       38041757.0         Asia      1.098793
# ...

# %%
filt =(df['code']=='AFG')
df = df.drop(index=df[filt].index)  # maskeleme ile rows silme(filtering)

# %%
df
# Out:
#           daterep  day  month  year  cases  deaths countandterr code  \
# 245    10/09/2020   10      9  2020    151       1      Albania  ALB
# 246    09/09/2020    9      9  2020    147       2      Albania  ALB
# 247    08/09/2020    8      9  2020    151       3      Albania  ALB
# 248    07/09/2020    7      9  2020    153       4      Albania  ALB
# 249    06/09/2020    6      9  2020    135       6      Albania  ALB
# ...           ...  ...    ...   ...    ...     ...          ...  ...
# 41832  25/03/2020   25      3  2020      0       0     Zimbabwe  ZWE
# 41833  24/03/2020   24      3  2020      0       1     Zimbabwe  ZWE
# 41834  23/03/2020   23      3  2020      0       0     Zimbabwe  ZWE
# 41835  22/03/2020   22      3  2020      1       0     Zimbabwe  ZWE
# 41836  21/03/2020   21      3  2020      1       0     Zimbabwe  ZWE
#
#        popdata2019 continentexp  density14pop
# 245      2862427.0       Europe     62.080186
# ...

# %%
df.sort_values(by=['deaths', 'cases'], ascending=False)
# Out:
#           daterep  day  month  year  cases  deaths              countandterr  \
# 40128  16/04/2020   16      4  2020  30148    4928  United_States_of_America
# 30391  14/08/2020   14      8  2020   9441    3935                      Peru
# 30412  24/07/2020   24      7  2020   4546    3887                      Peru
# 11396  07/09/2020    7      9  2020  -8261    3800                   Ecuador
# 40126  18/04/2020   18      4  2020  30833    3770  United_States_of_America
# ...           ...  ...    ...   ...    ...     ...                       ...
# 35726  12/08/2020   12      8  2020   3172      -2                     Spain
# 10173  06/07/2020    6      7  2020     75      -3                   Czechia
# 19866  25/06/2020   25      6  2020    577     -31                     Italy
# 21649  24/08/2020   24      8  2020    237    -443                Kyrgyzstan
# 35805  25/05/2020   25      5  2020   -372   -1918                     Spain
#
# ...

# %%
df['deaths'] = abs(df['deaths'])
df['cases'] = abs(df['cases'])

# %%
df.sort_values(by=['cases', 'deaths'], ascending=[False, True])
# Out:
#           daterep  day  month  year  cases  deaths countandterr code  \
# 18100  10/09/2020   10      9  2020  95735    1172        India  IND
# 18103  07/09/2020    7      9  2020  90802    1016        India  IND
# 18104  06/09/2020    6      9  2020  90632    1065        India  IND
# 18101  09/09/2020    9      9  2020  89706    1115        India  IND
# 18105  05/09/2020    5      9  2020  86432    1089        India  IND
# ...           ...  ...    ...   ...    ...     ...          ...  ...
# 6952   20/04/2020   20      4  2020      0      21     Cameroon  CMR
# 13885  26/06/2020   26      6  2020      0      21       France  FRA
# 26274  19/08/2020   19      8  2020      0      23      Morocco  MAR
# 1453   27/06/2020   27      6  2020      0      43    Argentina  ARG
# 20854  25/08/2020   25      8  2020      0     108   Kazakhstan  KAZ
#
#         popdata2019 continentexp  density14pop
# 18100  1.366418e+09         Asia     84.573623
# ...

# %%
df.sort_index()
# Out:
#           daterep  day  month  year  cases  deaths countandterr code  \
# 245    10/09/2020   10      9  2020    151       1      Albania  ALB
# 246    09/09/2020    9      9  2020    147       2      Albania  ALB
# 247    08/09/2020    8      9  2020    151       3      Albania  ALB
# 248    07/09/2020    7      9  2020    153       4      Albania  ALB
# 249    06/09/2020    6      9  2020    135       6      Albania  ALB
# ...           ...  ...    ...   ...    ...     ...          ...  ...
# 41832  25/03/2020   25      3  2020      0       0     Zimbabwe  ZWE
# 41833  24/03/2020   24      3  2020      0       1     Zimbabwe  ZWE
# 41834  23/03/2020   23      3  2020      0       0     Zimbabwe  ZWE
# 41835  22/03/2020   22      3  2020      1       0     Zimbabwe  ZWE
# 41836  21/03/2020   21      3  2020      1       0     Zimbabwe  ZWE
#
#        popdata2019 continentexp  density14pop
# 245      2862427.0       Europe     62.080186
# ...

# %%
df.sort_values(by='density14pop')
# Out:
#           daterep  day  month  year  cases  deaths countandterr code  \
# 23314  10/09/2020   10      9  2020     49       0   Luxembourg  LUX
# 23320  04/09/2020    4      9  2020      0       0   Luxembourg  LUX
# 23315  09/09/2020    9      9  2020     24       0   Luxembourg  LUX
# 23325  30/08/2020   30      8  2020      0       0   Luxembourg  LUX
# 23319  05/09/2020    5      9  2020    109       0   Luxembourg  LUX
# ...           ...  ...    ...   ...    ...     ...          ...  ...
# 41832  25/03/2020   25      3  2020      0       0     Zimbabwe  ZWE
# 41833  24/03/2020   24      3  2020      0       1     Zimbabwe  ZWE
# 41834  23/03/2020   23      3  2020      0       0     Zimbabwe  ZWE
# 41835  22/03/2020   22      3  2020      1       0     Zimbabwe  ZWE
# 41836  21/03/2020   21      3  2020      1       0     Zimbabwe  ZWE
#
#        popdata2019 continentexp  density14pop
# 23314     613894.0       Europe   -147.419587
# ...

# %%
df['deaths'].nlargest(10)
# Out:
# 40128    4928
# 30391    3935
# 30412    3887
# 11396    3800
# 40126    3770
# 40120    3179
# 40114    2611
# 40122    2524
# 40057    2437
# 40129    2408
# Name: deaths, dtype: int64

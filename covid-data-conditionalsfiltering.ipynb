# %%
import pandas as pd

# %%
df = pd.read_csv('download.csv')

# %%
df = pd.DataFrame(df)

# %%
df.head(2)
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  10/09/2020   10      9  2020     24       2             Afghanistan    AF
# 1  09/09/2020    9      9  2020     26       3             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           1.098793
# 1                                           1.180282

# %%
filtTURFRA = (df['countryterritoryCode'] == 'TUR') | (df['countryterritoryCode'] == 'FRA')

# %%
df[filtTURFRA]
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 13809  10/09/2020   10      9  2020   8577      30                  France
# 13810  09/09/2020    9      9  2020   6544      38                  France
# 13811  08/09/2020    8      9  2020   4203      25                  France
# 13812  07/09/2020    7      9  2020   7071       3                  France
# 13813  06/09/2020    6      9  2020   8550      12                  France
# ...           ...  ...    ...   ...    ...     ...                     ...
# 38770  18/03/2020   18      3  2020     51       0                  Turkey
# 38771  17/03/2020   17      3  2020     29       0                  Turkey
# 38772  16/03/2020   16      3  2020     16       0                  Turkey
# 38773  13/03/2020   13      3  2020      1       0                  Turkey
# 38774  12/03/2020   12      3  2020      1       0                  Turkey
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
dataTUR = df[df['countryterritoryCode'] == 'TUR']

# %%
df.loc[-filtTURFRA, 'cases'] #filterin am tersine işaret eder
# Out:
# 0        24
# 1        26
# 2        96
# 3        74
# 4        20
#          ..
# 41832     0
# 41833     0
# 41834     0
# 41835     1
# 41836     1
# Name: cases, Length: 41401, dtype: int64

# %%
dataTUR
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 38594  10/09/2020   10      9  2020   1673      55                  Turkey
# 38595  09/09/2020    9      9  2020   1761      52                  Turkey
# 38596  08/09/2020    8      9  2020   1703      57                  Turkey
# 38597  07/09/2020    7      9  2020   1578      53                  Turkey
# 38598  06/09/2020    6      9  2020   1673      56                  Turkey
# ...           ...  ...    ...   ...    ...     ...                     ...
# 38770  18/03/2020   18      3  2020     51       0                  Turkey
# 38771  17/03/2020   17      3  2020     29       0                  Turkey
# 38772  16/03/2020   16      3  2020     16       0                  Turkey
# 38773  13/03/2020   13      3  2020      1       0                  Turkey
# 38774  12/03/2020   12      3  2020      1       0                  Turkey
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
dataFRA = df[df['countryterritoryCode'] == 'FRA']

# %%
dataESP = df[df['countryterritoryCode'] == 'ESP']

# %%
dataESP.shape
# Out:
# (254, 12)

# %%
df.loc[filtTURFRA, ['deaths', 'cases', 'countryterritoryCode']]
# Out:
#        deaths  cases countryterritoryCode
# 13809      30   8577                  FRA
# 13810      38   6544                  FRA
# 13811      25   4203                  FRA
# 13812       3   7071                  FRA
# 13813      12   8550                  FRA
# ...       ...    ...                  ...
# 38770       0     51                  TUR
# 38771       0     29                  TUR
# 38772       0     16                  TUR
# 38773       0      1                  TUR
# 38774       0      1                  TUR
#
# [436 rows x 3 columns]

# %%
countries = ['TUR', 'FRA', 'ESP']
filt = df['countryterritoryCode'].isin(countries)

# %%
dataTrFrEs = df.loc[filt]

# %%
filtAs = df['continentExp'].str.contains('Asia', na=False)

# %%
df.loc[filtAs]
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      10/09/2020   10      9  2020     24       2             Afghanistan
# 1      09/09/2020    9      9  2020     26       3             Afghanistan
# 2      08/09/2020    8      9  2020     96       3             Afghanistan
# 3      07/09/2020    7      9  2020     74       2             Afghanistan
# 4      06/09/2020    6      9  2020     20       0             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 41482  14/04/2020   14      4  2020      0       0                   Yemen
# 41483  13/04/2020   13      4  2020      0       0                   Yemen
# 41484  12/04/2020   12      4  2020      0       0                   Yemen
# 41485  11/04/2020   11      4  2020      0       0                   Yemen
# 41486  10/04/2020   10      4  2020      1       0                   Yemen
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
dataTrFrEs.set_index('cases').sort_index(ascending=False).head(8)
# Out:
#           dateRep  day  month  year  deaths countriesAndTerritories geoId  \
# cases
# 26560  07/09/2020    7      9  2020      98                   Spain    ES
# 23572  31/08/2020   31      8  2020      83                   Spain    ES
# 19382  24/08/2020   24      8  2020      34                   Spain    ES
# 16269  17/08/2020   17      8  2020      29                   Spain    ES
# 10476  04/09/2020    4      9  2020     184                   Spain    ES
# 9779   28/08/2020   28      8  2020      15                   Spain    ES
# 9658   27/08/2020   27      8  2020      25                   Spain    ES
# 9181   27/03/2020   27      3  2020     655                   Spain    ES
#
#       countryterritoryCode  popData2019 continentExp  \
# cases
# 26560                  ESP   46937060.0       Europe
# 23572                  ESP   46937060.0       Europe
# 19382                  ESP   46937060.0       Europe
# 16269                  ESP   46937060.0       Europe
# ...

# %%
import pandas as pd
import numpy as np

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('download.csv', na_values=na_vals, parse_dates=['dateRep'])

# %%
df.head(2)

df.replace('NA', np.nan, inplace=True)
df.replace('AFG', np.nan, inplace=True)
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-10-09   10      9  2020     24       2             Afghanistan
# 1     2020-09-09    9      9  2020     26       3             Afghanistan
# 2     2020-08-09    8      9  2020     96       3             Afghanistan
# 3     2020-07-09    7      9  2020     74       2             Afghanistan
# 4     2020-06-09    6      9  2020     20       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41832 2020-03-25   25      3  2020      0       0                Zimbabwe
# 41833 2020-03-24   24      3  2020      0       1                Zimbabwe
# 41834 2020-03-23   23      3  2020      0       0                Zimbabwe
# 41835 2020-03-22   22      3  2020      1       0                Zimbabwe
# 41836 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
df.rename(columns = {'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': 'densityPop'}, inplace=True)

# %%
df.head(2)
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-10-09   10      9  2020     24       2             Afghanistan    AF
# 1 2020-09-09    9      9  2020     26       3             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  densityPop
# 0                  NaN   38041757.0         Asia    1.098793
# 1                  NaN   38041757.0         Asia    1.180282

# %%
df.shape
# Out:
# (41837, 12)

# %%
df.dropna()
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 245   2020-10-09   10      9  2020    151       1                 Albania
# 246   2020-09-09    9      9  2020    147       2                 Albania
# 247   2020-08-09    8      9  2020    151       3                 Albania
# 248   2020-07-09    7      9  2020    153       4                 Albania
# 249   2020-06-09    6      9  2020    135       6                 Albania
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41819 2020-07-04    7      4  2020      0       0                Zimbabwe
# 41820 2020-06-04    6      4  2020      0       0                Zimbabwe
# 41821 2020-05-04    5      4  2020      0       0                Zimbabwe
# 41822 2020-04-04    4      4  2020      1       0                Zimbabwe
# 41823 2020-03-04    3      4  2020      0       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  densityPop
# ...

# %%
df.dropna(axis='columns', how='all')  # nan ve bos olanları siler ama hepsi columdaki bosa siler
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-10-09   10      9  2020     24       2             Afghanistan
# 1     2020-09-09    9      9  2020     26       3             Afghanistan
# 2     2020-08-09    8      9  2020     96       3             Afghanistan
# 3     2020-07-09    7      9  2020     74       2             Afghanistan
# 4     2020-06-09    6      9  2020     20       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41832 2020-03-25   25      3  2020      0       0                Zimbabwe
# 41833 2020-03-24   24      3  2020      0       1                Zimbabwe
# 41834 2020-03-23   23      3  2020      0       0                Zimbabwe
# 41835 2020-03-22   22      3  2020      1       0                Zimbabwe
# 41836 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  densityPop
# ...

# %%
df.dropna(axis='columns', how='any')  # sutuna gore sildi bu sutunların tamamında nan yok....
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-10-09   10      9  2020     24       2             Afghanistan
# 1     2020-09-09    9      9  2020     26       3             Afghanistan
# 2     2020-08-09    8      9  2020     96       3             Afghanistan
# 3     2020-07-09    7      9  2020     74       2             Afghanistan
# 4     2020-06-09    6      9  2020     20       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41832 2020-03-25   25      3  2020      0       0                Zimbabwe
# 41833 2020-03-24   24      3  2020      0       1                Zimbabwe
# 41834 2020-03-23   23      3  2020      0       0                Zimbabwe
# 41835 2020-03-22   22      3  2020      1       0                Zimbabwe
# 41836 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       continentExp
# 0             Asia
# 1             Asia
# ...

# %%
df.dropna(axis='index', how='all', subset=['deaths','cases'])
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-10-09   10      9  2020     24       2             Afghanistan
# 1     2020-09-09    9      9  2020     26       3             Afghanistan
# 2     2020-08-09    8      9  2020     96       3             Afghanistan
# 3     2020-07-09    7      9  2020     74       2             Afghanistan
# 4     2020-06-09    6      9  2020     20       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41832 2020-03-25   25      3  2020      0       0                Zimbabwe
# 41833 2020-03-24   24      3  2020      0       1                Zimbabwe
# 41834 2020-03-23   23      3  2020      0       0                Zimbabwe
# 41835 2020-03-22   22      3  2020      1       0                Zimbabwe
# 41836 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  densityPop
# ...

# %%
df.isna()  #nan olanları true gösteren bir maskeleme methodu
# Out:
#        dateRep    day  month   year  cases  deaths  countriesAndTerritories  \
# 0        False  False  False  False  False   False                    False
# 1        False  False  False  False  False   False                    False
# 2        False  False  False  False  False   False                    False
# 3        False  False  False  False  False   False                    False
# 4        False  False  False  False  False   False                    False
# ...        ...    ...    ...    ...    ...     ...                      ...
# 41832    False  False  False  False  False   False                    False
# 41833    False  False  False  False  False   False                    False
# 41834    False  False  False  False  False   False                    False
# 41835    False  False  False  False  False   False                    False
# 41836    False  False  False  False  False   False                    False
#
# ...

# %%
df.fillna('BRA')  # tum NaN olanları BRA ya cevirdik
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-10-09   10      9  2020     24       2             Afghanistan
# 1     2020-09-09    9      9  2020     26       3             Afghanistan
# 2     2020-08-09    8      9  2020     96       3             Afghanistan
# 3     2020-07-09    7      9  2020     74       2             Afghanistan
# 4     2020-06-09    6      9  2020     20       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41832 2020-03-25   25      3  2020      0       0                Zimbabwe
# 41833 2020-03-24   24      3  2020      0       1                Zimbabwe
# 41834 2020-03-23   23      3  2020      0       0                Zimbabwe
# 41835 2020-03-22   22      3  2020      1       0                Zimbabwe
# 41836 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp densityPop
# ...

# %%
df.fillna(0)
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-10-09   10      9  2020     24       2             Afghanistan
# 1     2020-09-09    9      9  2020     26       3             Afghanistan
# 2     2020-08-09    8      9  2020     96       3             Afghanistan
# 3     2020-07-09    7      9  2020     74       2             Afghanistan
# 4     2020-06-09    6      9  2020     20       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41832 2020-03-25   25      3  2020      0       0                Zimbabwe
# 41833 2020-03-24   24      3  2020      0       1                Zimbabwe
# 41834 2020-03-23   23      3  2020      0       0                Zimbabwe
# 41835 2020-03-22   22      3  2020      1       0                Zimbabwe
# 41836 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  densityPop
# ...

# %%
df.dtypes
# Out:
# dateRep                    datetime64[ns]
# day                                 int64
# month                               int64
# year                                int64
# cases                               int64
# deaths                              int64
# countriesAndTerritories            object
# geoId                              object
# countryterritoryCode               object
# popData2019                       float64
# continentExp                       object
# densityPop                        float64
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
df['deaths'] = df['deaths'].astype(float)

# %%
df.dtypes
# Out:
# dateRep                    datetime64[ns]
# day                                 int64
# month                               int64
# year                                int64
# cases                               int64
# deaths                            float64
# countriesAndTerritories            object
# geoId                              object
# countryterritoryCode               object
# popData2019                       float64
# continentExp                       object
# densityPop                        float64
# dtype: object

# %%
df['deaths'].mean()
# Out:
# 21.60745273322657

# %%
df['densityPop'].tail(20).mean()
# Out:
# 0.051698082857142856

# %%
df['densityPop'].tail(20).unique()
# Out:
# array([0.05462439, 0.04779634,        nan])

# %%
df['densityPop'].replace(np.nan, 0, inplace=True)

# %%
df['densityPop'].tail(20).unique()
# Out:
# array([0.05462439, 0.04779634, 0.        ])

# %%
# date time and series working

# %%
df.shape
# Out:
# (41837, 12)

# %%
df.loc[0,'dateRep'].day_name()
# Out:
# 'Friday'

# %%
df['dateRep'] = pd.to_datetime(df['dateRep'])
# sometimes not found avalailable format so you should make change on it.
#(....., format='%Y-%m-%d %I-%p')

# %%
df.loc[0,'dateRep'].day_name()   # time series gzelliği
# Out:
# 'Friday'

# %%
df['dateRep'].dt.day_name()
# Out:
# 0           Friday
# 1        Wednesday
# 2           Sunday
# 3         Thursday
# 4          Tuesday
#            ...
# 41832    Wednesday
# 41833      Tuesday
# 41834       Monday
# 41835       Sunday
# 41836     Saturday
# Name: dateRep, Length: 41837, dtype: object

# %%
df['dayofweek'] = df['dateRep'].dt.day_name()

# %%
df.head(3)
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-10-09   10      9  2020     24     2.0             Afghanistan    AF
# 1 2020-09-09    9      9  2020     26     3.0             Afghanistan    AF
# 2 2020-08-09    8      9  2020     96     3.0             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  densityPop  dayofweek
# 0                  NaN   38041757.0         Asia    1.098793     Friday
# 1                  NaN   38041757.0         Asia    1.180282  Wednesday
# 2                  NaN   38041757.0         Asia    1.114565     Sunday

# %%
df['dateRep'].min()
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
df['dateRep'].max()
# Out:
# Timestamp('2020-12-08 00:00:00')

# %%
df['dateRep'].max() - df['dateRep'].min()
# Out:
# Timedelta('343 days 00:00:00')

# %%
filt = (df['dateRep'] > '2019') # & (.....etc.)
df.loc[filt]
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-10-09   10      9  2020     24     2.0             Afghanistan
# 1     2020-09-09    9      9  2020     26     3.0             Afghanistan
# 2     2020-08-09    8      9  2020     96     3.0             Afghanistan
# 3     2020-07-09    7      9  2020     74     2.0             Afghanistan
# 4     2020-06-09    6      9  2020     20     0.0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 41832 2020-03-25   25      3  2020      0     0.0                Zimbabwe
# 41833 2020-03-24   24      3  2020      0     1.0                Zimbabwe
# 41834 2020-03-23   23      3  2020      0     0.0                Zimbabwe
# 41835 2020-03-22   22      3  2020      1     0.0                Zimbabwe
# 41836 2020-03-21   21      3  2020      1     0.0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  densityPop  \
# ...

# %%
#df.set_index('dateRep')

# %%
# %matplotlib inline

# %%
df['deaths'].plot()
# Out:
# <AxesSubplot:>

# %%
df.set_index('dateRep', inplace=True)  #INPLCE TRUE YU UNUTMUSSSUN

# %%
filt = (df['geoId'] == 'ZW')
zimbabwe = df.loc[filt]

# %%
zimbabwe
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-10-09   10      9  2020     41     4.0                Zimbabwe    ZW
# 2020-09-09    9      9  2020     90     8.0                Zimbabwe    ZW
# 2020-08-09    8      9  2020    321     3.0                Zimbabwe    ZW
# 2020-07-09    7      9  2020    140     1.0                Zimbabwe    ZW
# 2020-06-09    6      9  2020      0     0.0                Zimbabwe    ZW
# ...         ...    ...   ...    ...     ...                     ...   ...
# 2020-03-25   25      3  2020      0     0.0                Zimbabwe    ZW
# 2020-03-24   24      3  2020      0     1.0                Zimbabwe    ZW
# 2020-03-23   23      3  2020      0     0.0                Zimbabwe    ZW
# 2020-03-22   22      3  2020      1     0.0                Zimbabwe    ZW
# 2020-03-21   21      3  2020      1     0.0                Zimbabwe    ZW
#
# ...

# %%
zimbabwe.resample('W').mean()
# Out:
#               day  month    year       cases    deaths  popData2019  \
# dateRep
# 2020-01-05   1.00   4.50  2020.0    0.500000  0.000000   14645473.0
# 2020-01-12   1.00   7.50  2020.0   45.750000  5.000000   14645473.0
# 2020-01-19    NaN    NaN     NaN         NaN       NaN          NaN
# 2020-01-26    NaN    NaN     NaN         NaN       NaN          NaN
# 2020-02-02    NaN    NaN     NaN         NaN       NaN          NaN
# 2020-02-09   2.00   6.50  2020.0   98.500000  0.500000   14645473.0
# 2020-02-16    NaN    NaN     NaN         NaN       NaN          NaN
# 2020-02-23    NaN    NaN     NaN         NaN       NaN          NaN
# 2020-03-01    NaN    NaN     NaN         NaN       NaN          NaN
# 2020-03-08   3.00   6.00  2020.0   55.400000  0.200000   14645473.0
# 2020-03-15   3.00   9.00  2020.0   79.000000  3.000000   14645473.0
# 2020-03-22  21.50   3.00  2020.0    1.000000  0.000000   14645473.0
# 2020-03-29  26.00   3.00  2020.0    0.714286  0.142857   14645473.0
# ...

# %%
zimbabwe.plot()
# Out:
# /home/kozan/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# /home/kozan/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# /home/kozan/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# /home/kozan/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:256: MatplotlibDeprecationWarning:
# ...

# %%
df.resample('W').agg({'deaths': 'mean', 'cases': 'max', 'densityPop': 'sum'})
# Out:
#                deaths    cases    densityPop
# dateRep
# 2020-01-05  15.499257  29917.0   9274.763975
# 2020-01-12  22.362440  69921.0  33266.591405
# 2020-01-19   0.004264    136.0      0.043901
# 2020-01-26   0.113006    665.0      0.737939
# 2020-02-02   0.432836   2590.0      5.242345
# 2020-02-09  23.576659  78357.0  43475.031921
# 2020-02-16   2.067164  15141.0     19.477857
# 2020-02-23   1.692964   2052.0     33.698784
# 2020-03-01   0.976546    909.0     63.758210
# 2020-03-08  20.839161  53399.0  31738.175804
# 2020-03-15  13.867816  83883.0  13582.706424
# 2020-03-22   6.830841   7123.0   7064.474951
# 2020-03-29  13.887547  19979.0  19453.690822
# 2020-04-05  18.285568  32425.0  19010.330189
# 2020-04-12  24.568182  83341.0  34122.074422
# 2020-04-19  36.373519  32922.0  41271.859034
# 2020-04-26  29.575905  48529.0  36162.080768
# 2020-05-03  21.997012  27326.0  18962.296726
# 2020-05-10  25.763855  86432.0  44759.893188
# 2020-05-17  24.271333  27143.0  21056.506877
# ...

# %%
df = pd.read_csv('survey_results_public.csv', index_col = 'Respondent')

# %%
df.head(2)
# Out:
#            Professional ProgramHobby         Country      University  \
# Respondent
# 1               Student    Yes, both   United States              No
# 2               Student    Yes, both  United Kingdom  Yes, full-time
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# 2                               Employed part-time
#
#                                               FormalEducation  \
# Respondent
# 1                                            Secondary school
# 2           Some college/university study without earning ...
#
#                                       MajorUndergrad  \
# Respondent
# 1                                                NaN
# 2           Computer science or software engineering
#
#                                        HomeRemote         CompanySize  \
# Respondent
# 1                                             NaN                 NaN
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_csv('modified.tsv', sep='\t')

# %%
india_df.to_excel('modified.xlsx')

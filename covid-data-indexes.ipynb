# %%
import pandas as pd

# %%
df = pd.read_csv('download.csv') #index_col='colums name'

# %%
df = pd.DataFrame(df)

# %%
df.head(2)
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  10/09/2020   10      9  2020     24       2             Afghanistan    AF
# 1  09/09/2020    9      9  2020     26       3             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           1.098793
# 1                                           1.180282

# %%
df['Cumulative_number_for_14_days_of_COVID-19_cases_per_100000']
# Out:
# 0        1.098793
# 1        1.180282
# 2        1.114565
# 3        1.048847
# 4        0.854324
#            ...
# 41832         NaN
# 41833         NaN
# 41834         NaN
# 41835         NaN
# 41836         NaN
# Name: Cumulative_number_for_14_days_of_COVID-19_cases_per_100000, Length: 41837, dtype: float64

# %%
#df.set_index('dateRep')

# %%
pd.set_option('display.max_rows', 40)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=41837, step=1)

# %%
df.loc[0]
# Out:
# dateRep                                                        10/09/2020
# day                                                                    10
# month                                                                   9
# year                                                                 2020
# cases                                                                  24
# deaths                                                                  2
# countriesAndTerritories                                       Afghanistan
# geoId                                                                  AF
# countryterritoryCode                                                  AFG
# popData2019                                                   3.80418e+07
# continentExp                                                         Asia
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000        1.09879
# Name: 0, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.set_index('deaths', inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#         index     dateRep  day  month  year  cases   countriesAndTerritories  \
# deaths
#  4928   40128  16/04/2020   16      4  2020  30148  United_States_of_America
#  3935   30391  14/08/2020   14      8  2020   9441                      Peru
#  3887   30412  24/07/2020   24      7  2020   4546                      Peru
#  3800   11396  07/09/2020    7      9  2020  -8261                   Ecuador
#  3770   40126  18/04/2020   18      4  2020  30833  United_States_of_America
# ...       ...         ...  ...    ...   ...    ...                       ...
# -2      35726  12/08/2020   12      8  2020   3172                     Spain
# -3      10173  06/07/2020    6      7  2020     75                   Czechia
# -31     19866  25/06/2020   25      6  2020    577                     Italy
# -443    21649  24/08/2020   24      8  2020    237                Kyrgyzstan
# -1918   35805  25/05/2020   25      5  2020   -372                     Spain
#
#        geoId countryterritoryCode  popData2019 continentExp  \
# deaths
#  4928     US                  USA  329064917.0      America
#  3935     PE                  PER   32510462.0      America
#  3887     PE                  PER   32510462.0      America
#  3800     EC                  ECU   17373657.0      America
#  3770     US                  USA  329064917.0      America
# ...      ...                  ...          ...          ...
# -2        ES                  ESP   46937060.0       Europe
# -3        CZ                  CZE   10649800.0       Europe
# -31       IT                  ITA   60359546.0       Europe
# -443      KG                  KGZ    6415851.0         Asia
# -1918     ES                  ESP   46937060.0       Europe
#
#         Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# deaths
#  4928                                          128.528743
#  3935                                          309.143561
#  3887                                          168.093582
#  3800                                           11.598019
#  3770                                          128.910430
# ...                                                   ...
# -2                                             100.438758
# -3                                              18.939323
# -31                                              6.042126
# -443                                            45.964284
# -1918                                           16.255812
#
# [41837 rows x 12 columns]
